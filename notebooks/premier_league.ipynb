# %%
import requests
import pandas as pd
import time

# %% [markdown]
# ## Club

# %%
def extract_team(season):
    # Professional headers to mimic a browser
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Origin": "https://www.premierleague.com",
        "Referer": "https://www.premierleague.com/"
    }

    url = f'https://sdp-prem-prod.premier-league-prod.pulselive.com/api/v1/competitions/8/seasons/{season}/teams?_limit=20'
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Check for errors
        data = response.json()
  
        teams_list = []
        
        # Iterate through the 'data' key in the JSON
        for team in data.get('data', []):
            stadium = team.get('stadium', {})
            
            record = {
                "team_id": team.get("id"),
                "season_id": season,
                "team_name": team.get("name"),
                "short_name": team.get("shortName"),
                "abbreviation": team.get("abbr"),
                "stadium_name": stadium.get("name"),
                "city": stadium.get("city"),
                "capacity": stadium.get("capacity"),
                "country": stadium.get("country")
            }
            teams_list.append(record)
        
        return pd.DataFrame(teams_list)
    except Exception as e:
        print(f"Failed to fetch club: {e}")

# Generate the DataFrame
df_club = extract_team(season=2015)

# Show result
df_club
# Out:
#    team_id  season_id             team_name   short_name abbreviation  \
# 0        3       2015               Arsenal      Arsenal          ARS
# 1        7       2015           Aston Villa      A Villa          AVL
# 2       91       2015           Bournemouth  Bournemouth          BOU
# 3        8       2015               Chelsea      Chelsea          CHE
# 4       31       2015        Crystal Palace     C Palace          CRY
# 5       11       2015               Everton      Everton          EVE
# 6       13       2015        Leicester City    Leicester          LEI
# 7       14       2015             Liverpool    Liverpool          LIV
# 8       43       2015       Manchester City     Man City          MCI
# 9        1       2015     Manchester United      Man Utd          MUN
# 10       4       2015      Newcastle United    Newcastle          NEW
# 11      45       2015          Norwich City      Norwich          NOR
# 12      20       2015           Southampton  Southampton          SOU
# 13     110       2015            Stoke City        Stoke          STK
# 14      56       2015            Sunderland   Sunderland          SUN
# 15      80       2015          Swansea City      Swansea          SWA
# 16       6       2015     Tottenham Hotspur        Spurs          TOT
# 17      57       2015               Watford      Watford          WAT
# 18      35       2015  West Bromwich Albion    West Brom          WBA
# 19      21       2015       West Ham United     West Ham          WHU
#
#           stadium_name           city  capacity  country
# 0     Emirates Stadium         London     60272  England
# 1           Villa Park     Birmingham     42682  England
# 2     Vitality Stadium    Bournemouth     10783  England
# 3      Stamford Bridge         London     41798  England
# 4        Selhurst Park         London     25073  England
# 5        Goodison Park      Liverpool     39571  England
# 6   King Power Stadium      Leicester     32312  England
# 7              Anfield      Liverpool     45276  England
# 8       Etihad Stadium     Manchester     46708  England
# 9         Old Trafford     Manchester     75635  England
# 10     St. James' Park      Newcastle     52405  England
# 11         Carrow Road        Norwich     27244  England
# 12  St. Mary's Stadium    Southampton     32505  England
# 13   Britannia Stadium          Stoke     27740  England
# 14    Stadium of Light     Sunderland     48707  England
# 15     Liberty Stadium        Swansea     20827    Wales
# 16     White Hart Lane         London     36284  England
# 17       Vicarage Road        Watford     22000  England
# 18       The Hawthorns  West Bromwich     26445  England
# 19       Boleyn Ground         London     35345  England

# %% [markdown]
# ## Player

# %%
def extract_squad(season_id, team_id):
    # Professional headers to mimic a browser
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Origin": "https://www.premierleague.com",
        "Referer": "https://www.premierleague.com/"
    }

    url = f'https://sdp-prem-prod.premier-league-prod.pulselive.com/api/v2/competitions/8/seasons/{season_id}/teams/{team_id}/squad'
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
  
        players_list = []
        team_info = data.get('team', {})
        
        # Iterate through the 'players' key in the JSON
        for p in data.get('players', []):
            name_data = p.get('name', {})
            date_data = p.get('dates', {})
            country_data = p.get('country', {})
            
            record = {
                "team_id": team_id,
                "season_id": season_id,
                "team_name": team_info.get("name"),
                "player_id": p.get("id"),
                "display_name": name_data.get("display"),
                "first_name": name_data.get("first"),
                "last_name": name_data.get("last"),
                "position": p.get("position"),
                "shirt_num": p.get("shirtNum"),
                "birth_date": date_data.get("birth"),
                "joined_club": date_data.get("joinedClub"),
                "nationality": country_data.get("country"),
                "height_cm": p.get("height"),
                "weight_kg": p.get("weight"),
                "preferred_foot": p.get("preferredFoot"),
                "is_loan": p.get("loan")
            }
            players_list.append(record)
        
        return pd.DataFrame(players_list)
    
    except Exception as e:
        print(f"Failed to fetch squad for team {team_id}: {e}")
        return pd.DataFrame()

# Generate the DataFrame for Arsenal (ID: 3) in the 2025 season
df_squad = extract_squad(season_id=2025, team_id=14)

# Show result
df_squad.head()
# Out:
#    team_id  season_id  team_name player_id          display_name  \
# 0       14       2025  Liverpool    116535        Alisson Becker
# 1       14       2025  Liverpool    449027  Giorgi Mamardashvili
# 2       14       2025  Liverpool    155503       Freddie Woodman
# 3       14       2025  Liverpool    586268           Ármin Pécsi
# 4       14       2025  Liverpool    617719        Kornel Misciur
#
#        first_name      last_name    position  shirt_num  birth_date  \
# 0  Alisson Ramsés         Becker  Goalkeeper          1  1992-10-02
# 1          Giorgi  Mamardashvili  Goalkeeper         25  2000-09-29
# 2         Freddie        Woodman  Goalkeeper         28  1997-03-04
# 3           Ármin          Pécsi  Goalkeeper         41  2005-02-24
# 4          Kornel        Misciur  Goalkeeper         74  2007-04-27
#
#   joined_club nationality  height_cm  weight_kg preferred_foot  is_loan
# 0  2018-07-19      Brazil        193       91.0          Right        0
# 1  2024-08-27     Georgia        197       90.0           Left        0
# 2  2025-07-01     England        188       83.0          Right        0
# 3  2025-06-07     Hungary        190        NaN          Right        0
# 4  2025-07-19      Poland        175       65.0          Right        0

# %% [markdown]
# ## Match

# %%
def fetch_full_season_data(competition_id=8, season=2025):
    all_matches = []
    
    # Iterate through all 38 matchweeks
    for mw in range(1, 2):
        print(f"Fetching Matchweek {mw}...")
        
        url = f"https://sdp-prem-prod.premier-league-prod.pulselive.com/api/v2/matches"
        params = {
            "competition": competition_id,
            "season": season,
            "matchweek": mw,
            "_limit": 20
        }
        
        try:
            # Adding headers to prevent being blocked
            headers = {"User-Agent": "Mozilla/5.0"}
            response = requests.get(url, params=params, headers=headers)
            response.raise_for_status()
            data = response.json()
            
            matches = data.get('data', [])
            
            for m in matches:
                # Logic to handle missing scores for PreMatch/Postponed games
                home = m.get('homeTeam', {})
                away = m.get('awayTeam', {})
                
                match_entry = {
                    "match_id": m.get("matchId"),
                    "season_id": season,
                    "matchweek": m.get("matchWeek"),
                    "kickoff": m.get("kickoff"),
                    "status": m.get("period"), # e.g., FullTime, PreMatch
                    "result_type": m.get("resultType"), # e.g., NormalResult, Postponed
                    "ground": m.get("ground"),
                    
                    # Home Team Details
                    "home_team": home.get("name"),
                    "home_team_id": home.get("id"),
                    "home_abbr": home.get("abbr"),
                    "home_score_ht": home.get("halfTimeScore"),
                    "home_score": home.get("score") if m.get("period") == "FullTime" else None,
                    "home_redcard": home.get("redCards"),
                    
                    # Away Team Details
                    "away_team": away.get("name"),
                    "away_team_id": away.get("id"),
                    "away_abbr": away.get("abbr"),
                    "away_score_ht": away.get("halfTimeScore"),
                    "away_score": away.get("score") if m.get("period") == "FullTime" else None,
                    "away_redcard": away.get("redCards"),
                    
                    "attendance": m.get("attendance")
                }
                all_matches.append(match_entry)
            
            # Small sleep to be polite to the server
            time.sleep(0.5)
            
        except Exception as e:
            print(f"Failed to fetch matchweek {mw}: {e}")

    return pd.DataFrame(all_matches)

# Execute and Save
df_season = fetch_full_season_data(season=2010)

# Data Analyst Quality Check
# print(df_season.info())
# df_season.to_csv("pl_season_2025_26.csv", index=False)
df_season.head(20)
# Out:
# Fetching Matchweek 1...
#   match_id  season_id  matchweek              kickoff    status   result_type  \
# 0   321657       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
# 1   321658       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
# 2   321659       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
# 3   321660       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
# 4   321661       2010          1  2010-08-14 17:30:00  FullTime  NormalResult
# 5   321662       2010          1  2010-08-15 16:00:00  FullTime  NormalResult
# 6   321663       2010          1  2010-08-16 20:00:00  FullTime  NormalResult
# 7   321664       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
# 8   321665       2010          1  2010-08-14 12:45:00  FullTime  NormalResult
# 9   321666       2010          1  2010-08-14 15:00:00  FullTime  NormalResult
#
#                             ground                home_team home_team_id  \
# 0           Villa Park, Birmingham              Aston Villa            7
# 1            Ewood Park, Blackburn         Blackburn Rovers            5
# 2                DW Stadium, Wigan           Wigan Athletic          111
# 3           Macron Stadium, Bolton         Bolton Wanderers           30
# 4          Stamford Bridge, London                  Chelsea            8
# 5               Anfield, Liverpool                Liverpool           14
# 6         Old Trafford, Manchester        Manchester United            1
# 7     Stadium of Light, Sunderland               Sunderland           56
# 8          White Hart Lane, London        Tottenham Hotspur            6
# 9  Molineux Stadium, Wolverhampton  Wolverhampton Wanderers           39
#
#   home_abbr  home_score_ht  home_score  home_redcard             away_team  \
# 0       AVL              2           3             0       West Ham United
# 1       BLA              1           1             0               Everton
# 2       WIG              0           0             0             Blackpool
# 3       BOL              0           0             0                Fulham
# 4       CHE              2           6             0  West Bromwich Albion
# 5       LIV              0           1             1               Arsenal
# 6       MUN              2           3             0      Newcastle United
# 7       SUN              1           2             1       Birmingham City
# 8       TOT              0           0             0       Manchester City
# 9       WOL              2           2             0            Stoke City
#
#   away_team_id away_abbr  away_score_ht  away_score  away_redcard  attendance
# 0           21       WHU              0           0             0       36604
# 1           11       EVE              0           0             0       25869
# 2           92       BPL              3           4             0       16152
# 3           54       FUL              0           0             0       20352
# 4           35       WBA              0           0             0       41589
# 5            3       ARS              0           1             1       44722
# 6            4       NEW              0           0             0       75221
# 7           41       BIR              0           2             0       38390
# 8           43       MCI              0           0             0       35928
# 9          110       STO              0           1             0       27850

# %%
from premier_league import PremierLeagueScraper

scraper = PremierLeagueScraper(season=2025)

# %%
df_match = scraper.get_matches()
df_match
# Out:
# Fetching Matchweek 1...
#   match_id  season_id  matchweek              kickoff    status   result_type  \
# 0  2561895       2025          1  2025-08-15 20:00:00  FullTime  NormalResult
# 1  2561896       2025          1  2025-08-16 12:30:00  FullTime  NormalResult
# 2  2561897       2025          1  2025-08-16 15:00:00  FullTime  NormalResult
# 3  2561898       2025          1  2025-08-17 14:00:00  FullTime  NormalResult
# 4  2561899       2025          1  2025-08-16 15:00:00  FullTime  NormalResult
# 5  2561900       2025          1  2025-08-16 15:00:00  FullTime  NormalResult
# 6  2561901       2025          1  2025-08-16 17:30:00  FullTime  NormalResult
# 7  2561902       2025          1  2025-08-17 14:00:00  FullTime  NormalResult
# 8  2561903       2025          1  2025-08-17 16:30:00  FullTime  NormalResult
# 9  2561904       2025          1  2025-08-18 20:00:00  FullTime  NormalResult
#
#                               ground                 home_team home_team_id  \
# 0                 Anfield, Liverpool                 Liverpool           14
# 1             Villa Park, Birmingham               Aston Villa            7
# 2   American Express Stadium, Falmer  Brighton and Hove Albion           36
# 3        The City Ground, Nottingham         Nottingham Forest           17
# 4       Stadium of Light, Sunderland                Sunderland           56
# 5  Tottenham Hotspur Stadium, London         Tottenham Hotspur            6
# 6    Molineux Stadium, Wolverhampton   Wolverhampton Wanderers           39
# 7            Stamford Bridge, London                   Chelsea            8
# 8           Old Trafford, Manchester         Manchester United            1
# 9                 Elland Road, Leeds              Leeds United            2
#
#   home_abbr  home_score_ht  home_score  home_redcard         away_team  \
# 0       LIV              1           4             0       Bournemouth
# 1       AVL              0           0             1  Newcastle United
# 2       BHA              0           1             0            Fulham
# 3       NFO              3           3             0         Brentford
# 4       SUN              0           3             0   West Ham United
# 5       TOT              1           3             0           Burnley
# 6       WOL              0           0             0   Manchester City
#
#      nationality  height_cm  weight_kg preferred_foot  is_loan
# 0          Spain      183.0       80.0          Right        0
# 1          Spain      189.0       84.0          Right        0
# 2        England      185.0       76.0          Right        0
# 3       Colombia      187.0       77.0          Right        0
# 4        England      185.0       75.0          Right        0
# ..           ...        ...        ...            ...      ...
# 649  South Korea      177.0       77.0          Right        0
# 650      Nigeria      197.0       97.0          Right        0
# 651     Paraguay      169.0       69.0           Left        0
# 652     Portugal      175.0        NaN          Right        0
# 653      England      178.0       68.0          Right        0
#
# [654 rows x 16 columns]

# %%
df_club = scraper.get_teams()
df_club
# Out:
#    team_id  season_id                 team_name     short_name abbreviation  \
# 0        3       2025                   Arsenal        Arsenal          ARS
# 1        7       2025               Aston Villa        A Villa          AVL
# 2       91       2025               Bournemouth    Bournemouth          BOU
# 3       94       2025                 Brentford      Brentford          BRE
# 4       36       2025  Brighton and Hove Albion       Brighton          BHA
# 5       90       2025                   Burnley        Burnley          BUR
# 6        8       2025                   Chelsea        Chelsea          CHE
# 7       31       2025            Crystal Palace       C Palace          CRY
# 8       11       2025                   Everton        Everton          EVE
# 9       54       2025                    Fulham         Fulham          FUL
# 10       2       2025              Leeds United          Leeds          LEE
# 11      14       2025                 Liverpool      Liverpool          LIV
# 12      43       2025           Manchester City       Man City          MCI
# 13       1       2025         Manchester United        Man Utd          MUN
# 14       4       2025          Newcastle United      Newcastle          NEW
# 15      17       2025         Nottingham Forest  Nott'm Forest          NFO
# 16      56       2025                Sunderland     Sunderland          SUN
# 17       6       2025         Tottenham Hotspur          Spurs          TOT
# 18      21       2025           West Ham United       West Ham          WHU
# 19      39       2025   Wolverhampton Wanderers         Wolves          WOL
#
#                  stadium_name           city  capacity  country
# 0            Emirates Stadium         London     60272  England
# 1                  Villa Park     Birmingham     42682  England
# 2            Vitality Stadium    Bournemouth     11286  England
# 3     Gtech Community Stadium      Brentford     17250  England
# 4    American Express Stadium         Falmer     30750  England
# 5                   Turf Moor        Burnley     21401  England
# 6             Stamford Bridge         London     41798  England
# 7               Selhurst Park         London     25486  England
# 8      Hill Dickinson Stadium      Liverpool     52888  England
# 9              Craven Cottage         London     29130  England
# 10                Elland Road          Leeds     37645  England
# 11                    Anfield      Liverpool     61276  England
# 12             Etihad Stadium     Manchester     55000  England
# 13               Old Trafford     Manchester     75635  England
# 14            St. James' Park      Newcastle     52405  England
# 15            The City Ground     Nottingham     30602  England
# 16           Stadium of Light     Sunderland     48707  England
# 17  Tottenham Hotspur Stadium         London     62850  England
# 18             London Stadium         London     62500  England
# 19           Molineux Stadium  Wolverhampton     31750  England

# %%
import pandas as pd

# %%
import pandas as pd

df_club = pd.DataFrame()
df_players = pd.DataFrame()
df_match = pd.DataFrame()

for s in range(2016, 2018):
    print(f'Start scraping season {s}...')
    scraper = PremierLeagueScraper(s)

    club_loop = scraper.get_teams()
    players_loop = scraper.get_all_squads()
    match_loop = scraper.get_matches()
    df_club = pd.concat([df_club, club_loop])
    df_players = pd.concat([df_players, players_loop])
    df_match = pd.concat([df_match, match_loop])

    print(f'Finish scraping season {s} !')
# Out:
# Start scraping season 2016...
# Fetching Squad for Team ID: 3...
# Fetching Squad for Team ID: 91...
# Fetching Squad for Team ID: 90...
# Fetching Squad for Team ID: 8...
# Fetching Squad for Team ID: 31...
# Fetching Squad for Team ID: 11...
# Fetching Squad for Team ID: 88...
# Fetching Squad for Team ID: 13...
# Fetching Squad for Team ID: 14...
# Fetching Squad for Team ID: 43...
# Fetching Squad for Team ID: 1...
# Fetching Squad for Team ID: 25...
# Fetching Squad for Team ID: 20...
# Fetching Squad for Team ID: 110...
# Fetching Squad for Team ID: 56...
# Fetching Squad for Team ID: 80...
# Fetching Squad for Team ID: 6...
# Fetching Squad for Team ID: 57...
# Fetching Squad for Team ID: 35...
# Fetching Squad for Team ID: 21...
# Fetching Matchweek 1...
# Finish scraping season 2016 !
# Start scraping season 2017...
# Fetching Squad for Team ID: 3...
# Fetching Squad for Team ID: 91...
# Fetching Squad for Team ID: 36...
# Fetching Squad for Team ID: 90...
# Fetching Squad for Team ID: 8...
# Fetching Squad for Team ID: 31...
# Fetching Squad for Team ID: 11...
# Fetching Squad for Team ID: 38...
# Fetching Squad for Team ID: 13...
# Fetching Squad for Team ID: 14...
# Fetching Squad for Team ID: 43...
# Fetching Squad for Team ID: 1...
# Fetching Squad for Team ID: 4...
# Fetching Squad for Team ID: 20...
# Fetching Squad for Team ID: 110...
# Fetching Squad for Team ID: 80...
# Fetching Squad for Team ID: 6...
# Fetching Squad for Team ID: 57...
# Fetching Squad for Team ID: 35...
# Fetching Squad for Team ID: 21...
# Fetching Matchweek 1...
# Finish scraping season 2017 !

# %%
df_club.sort_values(['team_name', 'season_id'], ascending=True)
# Out:
#    team_id  season_id                 team_name     short_name abbreviation  \
# 0        3       2016                   Arsenal        Arsenal          ARS
# 0        3       2017                   Arsenal        Arsenal          ARS
# 1       91       2016               Bournemouth    Bournemouth          BOU
# 1       91       2017               Bournemouth    Bournemouth          BOU
# 2       36       2017  Brighton and Hove Albion       Brighton          BHA
# 2       90       2016                   Burnley        Burnley          BRN
# 3       90       2017                   Burnley        Burnley          BRN
# 3        8       2016                   Chelsea        Chelsea          CHE
# 4        8       2017                   Chelsea        Chelsea          CHE
# 4       31       2016            Crystal Palace       C Palace          CRY
# 5       31       2017            Crystal Palace       C Palace          CRY
# 5       11       2016                   Everton        Everton          EVE
# 6       11       2017                   Everton        Everton          EVE
# 7       38       2017         Huddersfield Town   Huddersfield          HUD
# 6       88       2016                 Hull City           Hull          HUL
# 7       13       2016            Leicester City      Leicester          LEI
# 8       13       2017            Leicester City      Leicester          LEI
# 8       14       2016                 Liverpool      Liverpool          LIV
