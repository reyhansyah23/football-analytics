# %%
import pandas as pd
import numpy as np
import os
import getpass
from datetime import datetime
from kaggle_loader import KaggleToSQLPipeline

# %%
# Connect to database

DB_USER = "root"
pwd = getpass.getpass(f"Enter password for {DB_USER}: ")

# Initialize the pipeline
pipe = KaggleToSQLPipeline(db_name="football", user=DB_USER, password=pwd, port="3307")

# Download the data

data_folder = pipe.download_data("kamrangayibov/football-data-european-top-5-leagues")

file_path = os.path.join(data_folder, r'kaggle_dataset/')
# Out:
# Validating database connection...
# Connection successful!
# --- Downloading kamrangayibov/football-data-european-top-5-leagues ---
# Data saved to: d:\Project\Data Analytics\venv\football_db\Codes\football-analytics\Python\datasets\kamrangayibov\football-data-european-top-5-leagues\versions\1

# %%
# Create a list containing only files that end with '.csv'
csv_files = [f for f in os.listdir(file_path) if f.endswith('.csv')]

print(csv_files)
# Out:
# ['coaches.csv', 'leagues.csv', 'matches.csv', 'players.csv', 'referees.csv', 'scores.csv', 'seasons.csv', 'stadiums.csv', 'standings.csv', 'teams.csv']

# %%
# Preview the dataset using pandas dataframe

csv_to_load = os.path.join(file_path, "coaches.csv")

coach_df = pd.read_csv(csv_to_load)
display(coach_df.head(10))
# Out:
#    coach_id                  name  team_id nationality
# 0        34                   NaN      354         NaN
# 1        35                   NaN      356         NaN
# 2        36                   NaN      389         NaN
# 3        37                   NaN      397         NaN
# 4        38                   NaN      402         NaN
# 5        39                   NaN      563         NaN
# 6        40                   NaN     1044         NaN
# 7       101          Kersten Kuhl        1     Germany
# 8       102  Pellegrino Matarazzo        2         USA
# 9       103           Xabi Alonso        3       Spain

# %%
# Preview the dataset using pandas dataframe

csv_to_load = os.path.join(file_path, "teams.csv")

team_df = pd.read_csv(csv_to_load)
display(team_df.head(10))
# Out:
#    team_id                      name  founded_year  stadium_id  league_id  \
# 0       77             Athletic Club        1898.0          61          3
# 1       78   Club Atlético de Madrid        1903.0          62          3
# 2       79                CA Osasuna        1920.0          63          3
# 3       81              FC Barcelona        1899.0          64          3
# 4       82                 Getafe CF        1946.0          65          3
# 5       83                Granada CF        1931.0          66          3
# 6       86            Real Madrid CF        1902.0          67          3
# 7       87  Rayo Vallecano de Madrid        1924.0          68          3
# 8       89              RCD Mallorca        1916.0          69          3
# 9       90       Real Betis Balompié        1907.0          70          3
#
#    coach_id                                 cresturl
# 0        61  https://crests.football-data.org/77.png
# 1        62  https://crests.football-data.org/78.svg
# 2        63  https://crests.football-data.org/79.svg
# 3        64  https://crests.football-data.org/81.svg
# 4        65  https://crests.football-data.org/82.png
# 5        66  https://crests.football-data.org/83.svg
# 6        67  https://crests.football-data.org/86.png
# 7        68  https://crests.football-data.org/87.svg
# 8        69  https://crests.football-data.org/89.png
# 9        70  https://crests.football-data.org/90.png

# %%
"""
source: https://en.wikipedia.org/wiki/List_of_Premier_League_managers
"""
# Out:
# '\nsource: https://en.wikipedia.org/wiki/List_of_Premier_League_managers\n'

# %%
# --- Usage Example ---
from scrape_pl_manager import WikiTableParser

parser = WikiTableParser('https://en.wikipedia.org/wiki/List_of_Premier_League_managers')
pl_coach = parser.parse_managers_table()
if pl_coach is not None:
    print(pl_coach.head(3))
# Out:
#                Name      Nat.     Club              From             Until  \
# 1     George Graham  Scotland  Arsenal       14 May 1986  21 February 1995
# 2  Stewart Houston‡  Scotland  Arsenal  22 February 1995       8 June 1995
# 3       Bruce Rioch  Scotland  Arsenal       8 June 1995    12 August 1996
#
#   Duration(days) Years inLeague Ref.
# 1           3205      1992–1995  [2]
# 2            106           1995  [3]
# 3            431      1995–1996  [2]

# %%
pl_coach['From'].fillna('')
# Out:
# 1            14 May 1986
# 2       22 February 1995
# 3            8 June 1995
# 4         12 August 1996
# 5      13 September 1996
#              ...
# 495     14 November 2022
# 496        9 August 2023
# 497     19 December 2024
# 498      2 November 2025
# 499     12 November 2025
# Name: From, Length: 499, dtype: object

# %%
pl_coach[pl_coach['From'].astype(str).str.contains('\[.*\]', regex=True)]
# Out:
#                     Name              Nat.                    Club  \
# 57           Gary O'Neil           England             Bournemouth
# 67      Roberto De Zerbi             Italy  Brighton & Hove Albion
# 179         Scott Parker           England                  Fulham
# 185           Iain Dowie  Northern Ireland               Hull City
# 187          Mike Phelan           England               Hull City
# 215    Craig Shakespeare           England          Leicester City
# 257  Ole Gunnar Solskjær            Norway       Manchester United
# 288          John Carver           England        Newcastle United
# 330         Chris Ramsey           England     Queens Park Rangers
# 368         Rubén Sellés             Spain             Southampton
# 460         Darren Moore           Jamaica    West Bromwich Albion
#
#                      From             Until Duration(days) Years inLeague  \
# 57      30 August 2022[a]      19 June 2023            293      2022–2023
# 67   18 September 2022[b]       19 May 2024           1195      2022–2024
# 179   28 February 2019[c]      28 June 2021            851  20192020–2021
# 185      17 March 2010[d]        9 May 2010             53           2010
# 187       22 July 2016[e]    3 January 2017            165      2016–2017
# 215   23 February 2017[f]   17 October 2017            236           2017
# 257   19 December 2018[g]  21 November 2021           1068      2018–2021
# 288     2 January 2015[h]      10 June 2015            159           2015
# 330    3 February 2015[i]   4 November 2015            274           2015
# 368   12 February 2023[j]       28 May 2023            105           2023
# 460       2 April 2018[k]      9 March 2019            341           2018
#
#      Ref.
# 57   [36]
# 67
# 179
# 185  [92]
# 187
# 215
# 257
# 288
# 330
# 368
# 460

# %%
pl_coach['Name'].str.contains('‡')
# Out:
# 1      False
# 2       True
# 3      False
# 4       True
# 5       True
#        ...
# 495    False
# 496    False
# 497    False
# 498     True
# 499    False
# Name: Name, Length: 499, dtype: bool

# %%
pl_coach = pl_coach.assign(
    is_incumbent = np.where(pl_coach['Name'].str.contains('†'), 1, 0),
    is_caretaker = np.where(pl_coach['Name'].str.contains('‡'), 1, 0),
    is_non_pl_incumbent = np.where(pl_coach['Name'].str.contains('§'), 1, 0)
)

pl_coach
# Out:
#                  Name              Nat.                     Club  \
# 1       George Graham          Scotland                  Arsenal
# 2    Stewart Houston‡          Scotland                  Arsenal
# 3         Bruce Rioch          Scotland                  Arsenal
# 4    Stewart Houston‡          Scotland                  Arsenal
# 5           Pat Rice‡  Northern Ireland                  Arsenal
# ..                ...               ...                      ...
# 495   Julen Lopetegui             Spain  Wolverhampton Wanderers
# 496       Gary O'Neil           England  Wolverhampton Wanderers
# 497     Vítor Pereira          Portugal  Wolverhampton Wanderers
# 498    James Collins‡           England  Wolverhampton Wanderers
# 499      Rob Edwards†             Wales  Wolverhampton Wanderers
#
#                   From              Until Duration(days) Years inLeague Ref.  \
# 1          14 May 1986   21 February 1995           3205      1992–1995  [2]
# 2     22 February 1995        8 June 1995            106           1995  [3]
# 3          8 June 1995     12 August 1996            431      1995–1996  [2]
# 4       12 August 1996  13 September 1996             32           1996  [3]
# 5    13 September 1996  30 September 1996             17           1996  [4]
# ..                 ...                ...            ...            ...  ...
# 495   14 November 2022      8 August 2023            267      2022–2023
# 496      9 August 2023   15 December 2024            494      2023–2024
# 497   19 December 2024    2 November 2025            318      2024–2025
# 498    2 November 2025   12 November 2025             10           2025
# 499   12 November 2025           Present*             44          2025–
#
#      is_incumbent  is_caretaker  is_non_pl_incumbent
# 1               0             0                    0
# 2               0             1                    0
# 3               0             0                    0
# 4               0             1                    0
# 5               0             1                    0
# ..            ...           ...                  ...
# 495             0             0                    0
# 496             0             0                    0
# 497             0             0                    0
# 498             0             1                    0
# 499             1             0                    0
#
# [499 rows x 11 columns]

# %%
pl_coach['from_check'] = pd.to_datetime(pl_coach['From'], errors='coerce').astype(str)
pl_coach['until_check'] = pd.to_datetime(pl_coach['Until'], errors='coerce').astype(str)

# %%
pl_coach[pl_coach['from_check'].str.contains('NaT', case=False) | pl_coach['until_check'].str.contains('NaT', case=False)]
# Out:
#                      Name                 Nat.                     Club  \
# 9           Mikel Arteta†                Spain                  Arsenal
# 32            Unai Emery†                Spain              Aston Villa
# 57            Gary O'Neil              England              Bournemouth
# 58         Andoni Iraola†                Spain              Bournemouth
# 64         Keith Andrews†  Republic of Ireland                Brentford
# 67       Roberto De Zerbi                Italy   Brighton & Hove Albion
# 68       Fabian Hürzeler†              Germany   Brighton & Hove Albion
# 74          Scott Parker†              England                  Burnley
# 111         Enzo Maresca†                Italy                  Chelsea
# 138       Oliver Glasner†              Austria           Crystal Palace
# 166          David Moyes†             Scotland                  Everton
# 179          Scott Parker              England                   Fulham
# 180          Marco Silva†             Portugal                   Fulham
# 185            Iain Dowie     Northern Ireland                Hull City
# 187           Mike Phelan              England                Hull City
# 193       Kieran McKenna§     Northern Ireland             Ipswich Town
# 205         Daniel Farke†              Germany             Leeds United
# 215     Craig Shakespeare              England           Leicester City
# 237            Arne Slot†          Netherlands                Liverpool
# 251        Pep Guardiola†                Spain          Manchester City
# 257   Ole Gunnar Solskjær               Norway        Manchester United
# 262         Ruben Amorim†             Portugal        Manchester United
# 288           John Carver              England         Newcastle United
# 293           Eddie Howe†              England         Newcastle United
# 312           Sean Dyche†              England        Nottingham Forest
# 330          Chris Ramsey              England      Queens Park Rangers
# 368          Rubén Sellés                Spain              Southampton
# 391        Régis Le Bris†               France               Sunderland
# 431         Thomas Frank†              Denmark        Tottenham Hotspur
# 460          Darren Moore              Jamaica     West Bromwich Albion
# 480  Nuno Espírito Santo†             Portugal          West Ham United
# 499          Rob Edwards†                Wales  Wolverhampton Wanderers
#
#                      From             Until Duration(days) Years inLeague  \
# 9        22 December 2019          Present*           2196          2019–
# 32        1 November 2022          Present*           1151          2022–
# 57      30 August 2022[a]      19 June 2023            293      2022–2023
# 58           19 June 2023          Present*            921          2023–
# 64           27 June 2025          Present*            182          2025–
# 67   18 September 2022[b]       19 May 2024           1195      2022–2024
# 68            2 July 2024          Present*            542          2024–
# 74            5 July 2024          Present*            539          2025–
# 111           1 July 2024          Present*            543          2024–
# 138      19 February 2024          Present*            676          2024–
# 166       11 January 2025          Present*            349          2025–
# 179   28 February 2019[c]      28 June 2021            851  20192020–2021
# 180           1 July 2021          Present*           1639          2022–
# 185      17 March 2010[d]        9 May 2010             53           2010
# 187       22 July 2016[e]    3 January 2017            165      2016–2017
# 193      16 December 2021          Present*           1471      2024–2025
# 205           4 July 2023          Present*            906          2025–
# 215   23 February 2017[f]   17 October 2017            236           2017
# 237           1 June 2024          Present*            573          2024–
# 251           1 July 2016          Present*           3465          2016–
# 257   19 December 2018[g]  21 November 2021           1068      2018–2021
# 262      11 November 2024          Present*            410          2024–
# 288     2 January 2015[h]      10 June 2015            159           2015
# 293       8 November 2021          Present*           1509          2021–
# 312       21 October 2025          Present*             66          2025–
# 330    3 February 2015[i]   4 November 2015            274           2015
# 368   12 February 2023[j]       28 May 2023            105           2023
# 391           1 July 2024          Present*            543          2025–
# 431          12 June 2025          Present*            197          2025–
# 460       2 April 2018[k]      9 March 2019            341           2018
# 480     27 September 2025          Present*             90          2025–
# 499      12 November 2025          Present*             44          2025–
#
#      Ref.  is_incumbent  is_caretaker  is_non_pl_incumbent  from_check  \
# 9     [8]             1             0                    0  2019-12-22
# 32                    1             0                    0  2022-11-01
# 57   [36]             0             0                    0         NaT
# 58   [37]             1             0                    0  2023-06-19
# 64                    1             0                    0  2025-06-27
# 67                    0             0                    0         NaT
# 68                    1             0                    0  2024-07-02
# 74                    1             0                    0  2024-07-05
# 111                   1             0                    0  2024-07-01
# 138                   1             0                    0  2024-02-19
# 166                   1             0                    0  2025-01-11
# 179                   0             0                    0         NaT
# 180                   1             0                    0  2021-07-01
# 185  [92]             0             0                    0         NaT
# 187                   0             0                    0         NaT
# 193                   0             0                    1  2021-12-16
# 205                   1             0                    0  2023-07-04
# 215                   0             0                    0         NaT
# 237                   1             0                    0  2024-06-01
# 251                   1             0                    0  2016-07-01
# 257                   0             0                    0         NaT
# 262                   1             0                    0  2024-11-11
# 288                   0             0                    0         NaT
# 293                   1             0                    0  2021-11-08
# 312                   1             0                    0  2025-10-21
# 330                   0             0                    0         NaT
# 368                   0             0                    0         NaT
# 391                   1             0                    0  2024-07-01
# 431                   1             0                    0  2025-06-12
# 460                   0             0                    0         NaT
# 480                   1             0                    0  2025-09-27
# 499                   1             0                    0  2025-11-12
#
#     until_check
# 9           NaT
# 32          NaT
# 57   2023-06-19
# 58          NaT
# 64          NaT
# 67   2024-05-19
# 68          NaT
# 74          NaT
# 111         NaT
# 138         NaT
# 166         NaT
# 179  2021-06-28
# 180         NaT
# 185  2010-05-09
# 187  2017-01-03
# 193         NaT
# 205         NaT
# 215  2017-10-17
# 237         NaT
# 251         NaT
# 257  2021-11-21
# 262         NaT
# 288  2015-06-10
# 293         NaT
# 312         NaT
# 330  2015-11-04
# 368  2023-05-28
# 391         NaT
# 431         NaT
# 460  2019-03-09
# 480         NaT
# 499         NaT

# %%
pl_coach[pl_coach['Until'].astype(str).str.contains('present', case=False)]
# Out:
#                      Name                 Nat.                     Club  \
# 9           Mikel Arteta†                Spain                  Arsenal
# 32            Unai Emery†                Spain              Aston Villa
# 58         Andoni Iraola†                Spain              Bournemouth
# 64         Keith Andrews†  Republic of Ireland                Brentford
# 68       Fabian Hürzeler†              Germany   Brighton & Hove Albion
# 74          Scott Parker†              England                  Burnley
# 111         Enzo Maresca†                Italy                  Chelsea
# 138       Oliver Glasner†              Austria           Crystal Palace
# 166          David Moyes†             Scotland                  Everton
# 180          Marco Silva†             Portugal                   Fulham
# 193       Kieran McKenna§     Northern Ireland             Ipswich Town
# 205         Daniel Farke†              Germany             Leeds United
# 237            Arne Slot†          Netherlands                Liverpool
# 251        Pep Guardiola†                Spain          Manchester City
# 262         Ruben Amorim†             Portugal        Manchester United
# 293           Eddie Howe†              England         Newcastle United
# 312           Sean Dyche†              England        Nottingham Forest
# 391        Régis Le Bris†               France               Sunderland
# 431         Thomas Frank†              Denmark        Tottenham Hotspur
# 480  Nuno Espírito Santo†             Portugal          West Ham United
# 499          Rob Edwards†                Wales  Wolverhampton Wanderers
#
#                   From     Until Duration(days) Years inLeague  Ref.  \
# 9     22 December 2019  Present*           2196          2019–   [8]
# 32     1 November 2022  Present*           1151          2022–
# 58        19 June 2023  Present*            921          2023–  [37]
# 64        27 June 2025  Present*            182          2025–
# 68         2 July 2024  Present*            542          2024–
# 74         5 July 2024  Present*            539          2025–
# 111        1 July 2024  Present*            543          2024–
# 138   19 February 2024  Present*            676          2024–
# 166    11 January 2025  Present*            349          2025–
# 180        1 July 2021  Present*           1639          2022–
# 193   16 December 2021  Present*           1471      2024–2025
# 205        4 July 2023  Present*            906          2025–
# 237        1 June 2024  Present*            573          2024–
# 251        1 July 2016  Present*           3465          2016–
# 262   11 November 2024  Present*            410          2024–
# 293    8 November 2021  Present*           1509          2021–
# 312    21 October 2025  Present*             66          2025–
# 391        1 July 2024  Present*            543          2025–
# 431       12 June 2025  Present*            197          2025–
# 480  27 September 2025  Present*             90          2025–
# 499   12 November 2025  Present*             44          2025–
#
#      is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check
# 9               1             0                    0  2019-12-22         NaT
# 32              1             0                    0  2022-11-01         NaT
# 58              1             0                    0  2023-06-19         NaT
# 64              1             0                    0  2025-06-27         NaT
# 68              1             0                    0  2024-07-02         NaT
# 74              1             0                    0  2024-07-05         NaT
# 111             1             0                    0  2024-07-01         NaT
# 138             1             0                    0  2024-02-19         NaT
# 166             1             0                    0  2025-01-11         NaT
# 180             1             0                    0  2021-07-01         NaT
# 193             0             0                    1  2021-12-16         NaT
# 205             1             0                    0  2023-07-04         NaT
# 237             1             0                    0  2024-06-01         NaT
# 251             1             0                    0  2016-07-01         NaT
# 262             1             0                    0  2024-11-11         NaT
# 293             1             0                    0  2021-11-08         NaT
# 312             1             0                    0  2025-10-21         NaT
# 391             1             0                    0  2024-07-01         NaT
# 431             1             0                    0  2025-06-12         NaT
# 480             1             0                    0  2025-09-27         NaT
# 499             1             0                    0  2025-11-12         NaT

# %%
pl_coach = pl_coach.assign(
    until_at = np.where(pl_coach['Until'].astype(str).str.contains('present', case=False), datetime.now().date().strftime('%d %B %Y'), pl_coach['Until'])
)

pl_coach['until_at'] = pd.to_datetime(pl_coach['until_at'], format='%d %B %Y')

pl_coach
# Out:
#                  Name              Nat.                     Club  \
# 1       George Graham          Scotland                  Arsenal
# 2    Stewart Houston‡          Scotland                  Arsenal
# 3         Bruce Rioch          Scotland                  Arsenal
# 4    Stewart Houston‡          Scotland                  Arsenal
# 5           Pat Rice‡  Northern Ireland                  Arsenal
# ..                ...               ...                      ...
# 495   Julen Lopetegui             Spain  Wolverhampton Wanderers
# 496       Gary O'Neil           England  Wolverhampton Wanderers
# 497     Vítor Pereira          Portugal  Wolverhampton Wanderers
# 498    James Collins‡           England  Wolverhampton Wanderers
# 499      Rob Edwards†             Wales  Wolverhampton Wanderers
#
#                   From              Until Duration(days) Years inLeague Ref.  \
# 1          14 May 1986   21 February 1995           3205      1992–1995  [2]
# 2     22 February 1995        8 June 1995            106           1995  [3]
# 3          8 June 1995     12 August 1996            431      1995–1996  [2]
# 4       12 August 1996  13 September 1996             32           1996  [3]
# 5    13 September 1996  30 September 1996             17           1996  [4]
# ..                 ...                ...            ...            ...  ...
# 495   14 November 2022      8 August 2023            267      2022–2023
# 496      9 August 2023   15 December 2024            494      2023–2024
# 497   19 December 2024    2 November 2025            318      2024–2025
# 498    2 November 2025   12 November 2025             10           2025
# 499   12 November 2025           Present*             44          2025–
#
#      is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check  \
# 1               0             0                    0  1986-05-14  1995-02-21
# 2               0             1                    0  1995-02-22  1995-06-08
# 3               0             0                    0  1995-06-08  1996-08-12
# 4               0             1                    0  1996-08-12  1996-09-13
# 5               0             1                    0  1996-09-13  1996-09-30
# ..            ...           ...                  ...         ...         ...
# 495             0             0                    0  2022-11-14  2023-08-08
# 496             0             0                    0  2023-08-09  2024-12-15
# 497             0             0                    0  2024-12-19  2025-11-02
# 498             0             1                    0  2025-11-02  2025-11-12
# 499             1             0                    0  2025-11-12         NaT
#
#       until_at
# 1   1995-02-21
# 2   1995-06-08
# 3   1996-08-12
# 4   1996-09-13
# 5   1996-09-30
# ..         ...
# 495 2023-08-08
# 496 2024-12-15
# 497 2025-11-02
# 498 2025-11-12
# 499 2025-12-28
#
# [499 rows x 14 columns]

# %%
pl_coach[pl_coach['from_check'].str.contains('NaT', case=False)]
# Out:
#                     Name              Nat.                    Club  \
# 57           Gary O'Neil           England             Bournemouth
# 67      Roberto De Zerbi             Italy  Brighton & Hove Albion
# 179         Scott Parker           England                  Fulham
# 185           Iain Dowie  Northern Ireland               Hull City
# 187          Mike Phelan           England               Hull City
# 215    Craig Shakespeare           England          Leicester City
# 257  Ole Gunnar Solskjær            Norway       Manchester United
# 288          John Carver           England        Newcastle United
# 330         Chris Ramsey           England     Queens Park Rangers
# 368         Rubén Sellés             Spain             Southampton
# 460         Darren Moore           Jamaica    West Bromwich Albion
#
#                      From             Until Duration(days) Years inLeague  \
# 57      30 August 2022[a]      19 June 2023            293      2022–2023
# 67   18 September 2022[b]       19 May 2024           1195      2022–2024
# 179   28 February 2019[c]      28 June 2021            851  20192020–2021
# 185      17 March 2010[d]        9 May 2010             53           2010
# 187       22 July 2016[e]    3 January 2017            165      2016–2017
# 215   23 February 2017[f]   17 October 2017            236           2017
# 257   19 December 2018[g]  21 November 2021           1068      2018–2021
# 288     2 January 2015[h]      10 June 2015            159           2015
# 330    3 February 2015[i]   4 November 2015            274           2015
# 368   12 February 2023[j]       28 May 2023            105           2023
# 460       2 April 2018[k]      9 March 2019            341           2018
#
#      Ref.  is_incumbent  is_caretaker  is_non_pl_incumbent from_check  \
# 57   [36]             0             0                    0        NaT
# 67                    0             0                    0        NaT
# 179                   0             0                    0        NaT
# 185  [92]             0             0                    0        NaT
# 187                   0             0                    0        NaT
# 215                   0             0                    0        NaT
# 257                   0             0                    0        NaT
# 288                   0             0                    0        NaT
# 330                   0             0                    0        NaT
# 368                   0             0                    0        NaT
# 460                   0             0                    0        NaT
#
#     until_check   until_at
# 57   2023-06-19 2023-06-19
# 67   2024-05-19 2024-05-19
# 179  2021-06-28 2021-06-28
# 185  2010-05-09 2010-05-09
# 187  2017-01-03 2017-01-03
# 215  2017-10-17 2017-10-17
# 257  2021-11-21 2021-11-21
# 288  2015-06-10 2015-06-10
# 330  2015-11-04 2015-11-04
# 368  2023-05-28 2023-05-28
# 460  2019-03-09 2019-03-09

# %%
pl_coach['from_at'] = pl_coach['From'].astype(str).str.replace('\[.*\]', '', regex=True)
pl_coach.loc[[57]]
# Out:
#            Name     Nat.         Club               From         Until  \
# 57  Gary O'Neil  England  Bournemouth  30 August 2022[a]  19 June 2023
#
#    Duration(days) Years inLeague  Ref.  is_incumbent  is_caretaker  \
# 57            293      2022–2023  [36]             0             0
#
#     is_non_pl_incumbent from_check until_check   until_at         from_at
# 57                    0        NaT  2023-06-19 2023-06-19  30 August 2022

# %%
pl_coach.loc[57:59]
# Out:
#               Name     Nat.           Club               From         Until  \
# 57     Gary O'Neil  England    Bournemouth  30 August 2022[a]  19 June 2023
# 58  Andoni Iraola†    Spain    Bournemouth       19 June 2023      Present*
# 59     Paul Jewell  England  Bradford City     6 January 1998  18 June 2000
#
#    Duration(days) Years inLeague  Ref.  is_incumbent  is_caretaker  \
# 57            293      2022–2023  [36]             0             0
# 58            921          2023–  [37]             1             0
# 59            894      1999–2000  [38]             0             0
#
#     is_non_pl_incumbent  from_check until_check   until_at         from_at
# 57                    0         NaT  2023-06-19 2023-06-19  30 August 2022
# 58                    0  2023-06-19         NaT 2025-12-28    19 June 2023
# 59                    0  1998-01-06  2000-06-18 2000-06-18  6 January 1998

# %%
pl_coach[pl_coach['From'].astype(str).str.contains('\[.*\]', regex=True)]
# Out:
#                     Name              Nat.                    Club  \
# 57           Gary O'Neil           England             Bournemouth
# 67      Roberto De Zerbi             Italy  Brighton & Hove Albion
# 179         Scott Parker           England                  Fulham
# 185           Iain Dowie  Northern Ireland               Hull City
# 187          Mike Phelan           England               Hull City
# 215    Craig Shakespeare           England          Leicester City
# 257  Ole Gunnar Solskjær            Norway       Manchester United
# 288          John Carver           England        Newcastle United
# 330         Chris Ramsey           England     Queens Park Rangers
# 368         Rubén Sellés             Spain             Southampton
# 460         Darren Moore           Jamaica    West Bromwich Albion
#
#                      From             Until Duration(days) Years inLeague  \
# 57      30 August 2022[a]      19 June 2023            293      2022–2023
# 67   18 September 2022[b]       19 May 2024           1195      2022–2024
# 179   28 February 2019[c]      28 June 2021            851  20192020–2021
# 185      17 March 2010[d]        9 May 2010             53           2010
# 187       22 July 2016[e]    3 January 2017            165      2016–2017
# 215   23 February 2017[f]   17 October 2017            236           2017
# 257   19 December 2018[g]  21 November 2021           1068      2018–2021
# 288     2 January 2015[h]      10 June 2015            159           2015
# 330    3 February 2015[i]   4 November 2015            274           2015
# 368   12 February 2023[j]       28 May 2023            105           2023
# 460       2 April 2018[k]      9 March 2019            341           2018
#
#      Ref.  is_incumbent  is_caretaker  is_non_pl_incumbent from_check  \
# 57   [36]             0             0                    0        NaT
# 67                    0             0                    0        NaT
# 179                   0             0                    0        NaT
# 185  [92]             0             0                    0        NaT
# 187                   0             0                    0        NaT
# 215                   0             0                    0        NaT
# 257                   0             0                    0        NaT
# 288                   0             0                    0        NaT
# 330                   0             0                    0        NaT
# 368                   0             0                    0        NaT
# 460                   0             0                    0        NaT
#
#     until_check   until_at            from_at
# 57   2023-06-19 2023-06-19     30 August 2022
# 67   2024-05-19 2024-05-19  18 September 2022
# 179  2021-06-28 2021-06-28   28 February 2019
# 185  2010-05-09 2010-05-09      17 March 2010
# 187  2017-01-03 2017-01-03       22 July 2016
# 215  2017-10-17 2017-10-17   23 February 2017
# 257  2021-11-21 2021-11-21   19 December 2018
# 288  2015-06-10 2015-06-10     2 January 2015
# 330  2015-11-04 2015-11-04    3 February 2015
# 368  2023-05-28 2023-05-28   12 February 2023
# 460  2019-03-09 2019-03-09       2 April 2018

# %%
pd.to_datetime(pl_coach.loc[[57]]['from_at'], format='%d %B %Y', errors='coerce').astype(str)
# Out:
# 57    2022-08-30
# Name: from_at, dtype: object

# %%
pl_coach = pl_coach.assign(
from_at = np.where(pl_coach['From'].astype(str).str.contains('\[.*\]', regex=True)
         , pd.to_datetime(pl_coach['from_at'], format='%d %B %Y', errors='coerce')
         , pd.to_datetime(pl_coach['from_at'], errors='coerce'))
)

pl_coach
# Out:
#                  Name              Nat.                     Club  \
# 1       George Graham          Scotland                  Arsenal
# 2    Stewart Houston‡          Scotland                  Arsenal
# 3         Bruce Rioch          Scotland                  Arsenal
# 4    Stewart Houston‡          Scotland                  Arsenal
# 5           Pat Rice‡  Northern Ireland                  Arsenal
# ..                ...               ...                      ...
# 495   Julen Lopetegui             Spain  Wolverhampton Wanderers
# 496       Gary O'Neil           England  Wolverhampton Wanderers
# 497     Vítor Pereira          Portugal  Wolverhampton Wanderers
# 498    James Collins‡           England  Wolverhampton Wanderers
# 499      Rob Edwards†             Wales  Wolverhampton Wanderers
#
#                   From              Until Duration(days) Years inLeague Ref.  \
# 1          14 May 1986   21 February 1995           3205      1992–1995  [2]
# 2     22 February 1995        8 June 1995            106           1995  [3]
# 3          8 June 1995     12 August 1996            431      1995–1996  [2]
# 4       12 August 1996  13 September 1996             32           1996  [3]
# 5    13 September 1996  30 September 1996             17           1996  [4]
# ..                 ...                ...            ...            ...  ...
# 495   14 November 2022      8 August 2023            267      2022–2023
# 496      9 August 2023   15 December 2024            494      2023–2024
# 497   19 December 2024    2 November 2025            318      2024–2025
# 498    2 November 2025   12 November 2025             10           2025
# 499   12 November 2025           Present*             44          2025–
#
#      is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check  \
# 1               0             0                    0  1986-05-14  1995-02-21
# 2               0             1                    0  1995-02-22  1995-06-08
# 3               0             0                    0  1995-06-08  1996-08-12
# 4               0             1                    0  1996-08-12  1996-09-13
# 5               0             1                    0  1996-09-13  1996-09-30
# ..            ...           ...                  ...         ...         ...
# 495             0             0                    0  2022-11-14  2023-08-08
# 496             0             0                    0  2023-08-09  2024-12-15
# 497             0             0                    0  2024-12-19  2025-11-02
# 498             0             1                    0  2025-11-02  2025-11-12
# 499             1             0                    0  2025-11-12         NaT
#
#       until_at    from_at
# 1   1995-02-21 1986-05-14
# 2   1995-06-08 1995-02-22
# 3   1996-08-12 1995-06-08
# 4   1996-09-13 1996-08-12
# 5   1996-09-30 1996-09-13
# ..         ...        ...
# 495 2023-08-08 2022-11-14
# 496 2024-12-15 2023-08-09
# 497 2025-11-02 2024-12-19
# 498 2025-11-12 2025-11-02
# 499 2025-12-28 2025-11-12
#
# [499 rows x 15 columns]

# %%
pl_coach['from_check'] = pd.to_datetime(pl_coach['from_at'], errors='coerce').astype(str)
pl_coach['until_check'] = pd.to_datetime(pl_coach['until_at'], errors='coerce').astype(str)

# %%
pl_coach[pl_coach['from_check'].str.contains('NaT', case=False) | pl_coach['until_check'].str.contains('NaT', case=False)]
# Out:
# Empty DataFrame
# Columns: [Name, Nat., Club, From, Until, Duration(days), Years inLeague, Ref., is_incumbent, is_caretaker, is_non_pl_incumbent, from_check, until_check, until_at, from_at]
# Index: []

# %%
pl_coach
# Out:
#                  Name              Nat.                     Club  \
# 1       George Graham          Scotland                  Arsenal
# 2    Stewart Houston‡          Scotland                  Arsenal
# 3         Bruce Rioch          Scotland                  Arsenal
# 4    Stewart Houston‡          Scotland                  Arsenal
# 5           Pat Rice‡  Northern Ireland                  Arsenal
# ..                ...               ...                      ...
# 495   Julen Lopetegui             Spain  Wolverhampton Wanderers
# 496       Gary O'Neil           England  Wolverhampton Wanderers
# 497     Vítor Pereira          Portugal  Wolverhampton Wanderers
# 498    James Collins‡           England  Wolverhampton Wanderers
# 499      Rob Edwards†             Wales  Wolverhampton Wanderers
#
#                   From              Until Duration(days) Years inLeague Ref.  \
# 1          14 May 1986   21 February 1995           3205      1992–1995  [2]
# 2     22 February 1995        8 June 1995            106           1995  [3]
# 3          8 June 1995     12 August 1996            431      1995–1996  [2]
# 4       12 August 1996  13 September 1996             32           1996  [3]
# 5    13 September 1996  30 September 1996             17           1996  [4]
# ..                 ...                ...            ...            ...  ...
# 495   14 November 2022      8 August 2023            267      2022–2023
# 496      9 August 2023   15 December 2024            494      2023–2024
# 497   19 December 2024    2 November 2025            318      2024–2025
# 498    2 November 2025   12 November 2025             10           2025
# 499   12 November 2025           Present*             44          2025–
#
#      is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check  \
# 1               0             0                    0  1986-05-14  1995-02-21
# 2               0             1                    0  1995-02-22  1995-06-08
# 3               0             0                    0  1995-06-08  1996-08-12
# 4               0             1                    0  1996-08-12  1996-09-13
# 5               0             1                    0  1996-09-13  1996-09-30
# ..            ...           ...                  ...         ...         ...
# 495             0             0                    0  2022-11-14  2023-08-08
# 496             0             0                    0  2023-08-09  2024-12-15
# 497             0             0                    0  2024-12-19  2025-11-02
# 498             0             1                    0  2025-11-02  2025-11-12
# 499             1             0                    0  2025-11-12  2025-12-28
#
#       until_at    from_at
# 1   1995-02-21 1986-05-14
# 2   1995-06-08 1995-02-22
# 3   1996-08-12 1995-06-08
# 4   1996-09-13 1996-08-12
# 5   1996-09-30 1996-09-13
# ..         ...        ...
# 495 2023-08-08 2022-11-14
# 496 2024-12-15 2023-08-09
# 497 2025-11-02 2024-12-19
# 498 2025-11-12 2025-11-02
# 499 2025-12-28 2025-11-12
#
# [499 rows x 15 columns]

# %%
coach_team = coach_df.merge(team_df[['team_id', 'name', 'league_id']].rename({'name':'club_name'}, axis=1), how='left', on='team_id')
coach_team = coach_team[coach_team['league_id']==1]
coach_team
# Out:
#     coach_id                 name  team_id  nationality  \
# 0         34                  NaN      354          NaN
# 1         35                  NaN      356          NaN
# 2         36                  NaN      389          NaN
# 3         37                  NaN      397          NaN
# 4         38                  NaN      402          NaN
# 5         39                  NaN      563          NaN
# 6         40                  NaN     1044          NaN
# 83        31          Gary O'Neil       76          NaN
# 84        21         Mikel Arteta       57        Spain
# 85        22           Unai Emery       58        Spain
# 86        26         Jürgen Klopp       64      Germany
# 87        23         Enzo Maresca       61        Italy
# 88        24           Sean Dyche       62      England
# 89        25          Marco Silva       63     Portugal
# 90        27        Pep Guardiola       65        Spain
# 91        28         Erik ten Hag       66  Netherlands
# 92        29           Eddie Howe       67      England
# 93        30     Ange Postecoglou       73       Greece
# 94        32      Vincent Kompany      328      Belgium
# 95        33  Nuno Espirito Santo      351     Portugal
#
#                   club_name  league_id
# 0            Crystal Palace          1
# 1          Sheffield United          1
# 2                Luton Town          1
# 3    Brighton & Hove Albion          1
# 4                 Brentford          1
# 5           West Ham United          1
# 6           AFC Bournemouth          1
# 83  Wolverhampton Wanderers          1
# 84                  Arsenal          1
# 85              Aston Villa          1
# 86                Liverpool          1
# 87                  Chelsea          1
# 88                  Everton          1
# 89                   Fulham          1
# 90          Manchester City          1
# 91        Manchester United          1
# 92         Newcastle United          1
# 93        Tottenham Hotspur          1
# 94                  Burnley          1
# 95        Nottingham Forest          1

# %%
coach_pl = coach_team.merge(pl_coach, how='left', left_on='club_name', right_on='Club')
coach_pl
# Out:
#      coach_id                 name  team_id nationality          club_name  \
# 0          34                  NaN      354         NaN     Crystal Palace
# 1          34                  NaN      354         NaN     Crystal Palace
# 2          34                  NaN      354         NaN     Crystal Palace
# 3          34                  NaN      354         NaN     Crystal Palace
# 4          34                  NaN      354         NaN     Crystal Palace
# ..        ...                  ...      ...         ...                ...
# 262        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 263        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 264        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 265        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 266        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
#
#      league_id                 Name       Nat.               Club  \
# 0            1        Steve Coppell    England     Crystal Palace
# 1            1           Alan Smith    England     Crystal Palace
# 2            1        Steve Coppell    England     Crystal Palace
# 3            1    Attilio Lombardo‡      Italy     Crystal Palace
# 4            1        Tomas Brolin‡     Sweden     Crystal Palace
# ..         ...                  ...        ...                ...
# 262          1         Ron Atkinson    England  Nottingham Forest
# 263          1         Steve Cooper      Wales  Nottingham Forest
# 264          1  Nuno Espírito Santo   Portugal  Nottingham Forest
# 265          1     Ange Postecoglou  Australia  Nottingham Forest
# 266          1          Sean Dyche†    England  Nottingham Forest
#
#                   From  ... Duration(days) Years inLeague        Ref.  \
# 0          3 June 1984  ...           3270      1992–1993        [67]
# 1          3 June 1993  ...            711      1994–1995        [67]
# 2     27 February 1997  ...            379      1997–1998        [67]
# 3        13 March 1998  ...             47           1998        [67]
# 4        13 March 1998  ...             47           1998        [67]
# ..                 ...  ...            ...            ...         ...
# 262    11 January 1999  ...            125           1999  [112][113]
# 263  21 September 2021  ...            819      2022–2023
# 264   20 December 2023  ...            629      2023–2025
# 265   9 September 2025  ...             39           2025
# 266    21 October 2025  ...             66          2025–
#
#     is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check  \
# 0            0.0           0.0                  0.0  1984-06-03  1993-05-17
# 1            0.0           0.0                  0.0  1993-06-03  1995-05-15
# 2            0.0           0.0                  0.0  1997-02-27  1998-03-13
# 3            0.0           1.0                  0.0  1998-03-13  1998-04-29
# 4            0.0           1.0                  0.0  1998-03-13  1998-04-29
# ..           ...           ...                  ...         ...         ...
# 262          0.0           0.0                  0.0  1999-01-11  1999-05-16
# 263          0.0           0.0                  0.0  2021-09-21  2023-12-19
# 264          0.0           0.0                  0.0  2023-12-20  2025-09-09
# 265          0.0           0.0                  0.0  2025-09-09  2025-10-18
# 266          1.0           0.0                  0.0  2025-10-21  2025-12-28
#
#       until_at    from_at
# 0   1993-05-17 1984-06-03
# 1   1995-05-15 1993-06-03
# 2   1998-03-13 1997-02-27
# 3   1998-04-29 1998-03-13
# 4   1998-04-29 1998-03-13
# ..         ...        ...
# 262 1999-05-16 1999-01-11
# 263 2023-12-19 2021-09-21
# 264 2025-09-09 2023-12-20
# 265 2025-10-18 2025-09-09
# 266 2025-12-28 2025-10-21
#
# [267 rows x 21 columns]

# %%
coach_pl.isnull().any()
# Out:
# coach_id               False
# name                    True
# team_id                False
# nationality             True
# club_name              False
# league_id              False
# Name                    True
# Nat.                    True
# Club                    True
# From                    True
# Until                   True
# Duration(days)          True
# Years inLeague          True
# Ref.                    True
# is_incumbent            True
# is_caretaker            True
# is_non_pl_incumbent     True
# from_check              True
# until_check             True
# until_at                True
# from_at                 True
# dtype: bool

# %%
coach_pl[coach_pl['Name'].isnull()]
# Out:
#     coach_id name  team_id nationality        club_name  league_id Name Nat.  \
# 54        40  NaN     1044         NaN  AFC Bournemouth          1  NaN  NaN
#
#    Club From  ... Duration(days) Years inLeague Ref. is_incumbent  \
# 54  NaN  NaN  ...            NaN            NaN  NaN          NaN
#
#     is_caretaker  is_non_pl_incumbent  from_check until_check until_at from_at
# 54           NaN                  NaN         NaN         NaN      NaT     NaT
#
# [1 rows x 21 columns]

# %%
pl_coach[pl_coach['Club'].str.contains('bournemouth', case=False)]
# Out:
#               Name     Nat.         Club               From           Until  \
# 55      Eddie Howe  England  Bournemouth    12 October 2012   1 August 2020
# 56    Scott Parker  England  Bournemouth       28 June 2021  30 August 2022
# 57     Gary O'Neil  England  Bournemouth  30 August 2022[a]    19 June 2023
# 58  Andoni Iraola†    Spain  Bournemouth       19 June 2023        Present*
#
#    Duration(days) Years inLeague  Ref.  is_incumbent  is_caretaker  \
# 55           2850      2015–2020  [35]             0             0
# 56            428           2022                   0             0
# 57            293      2022–2023  [36]             0             0
# 58            921          2023–  [37]             1             0
#
#     is_non_pl_incumbent  from_check until_check   until_at    from_at
# 55                    0  2012-10-12  2020-08-01 2020-08-01 2012-10-12
# 56                    0  2021-06-28  2022-08-30 2022-08-30 2021-06-28
# 57                    0  2022-08-30  2023-06-19 2023-06-19 2022-08-30
# 58                    0  2023-06-19  2025-12-28 2025-12-28 2023-06-19

# %%
pl_coach['Club'] = pl_coach['Club'].str.replace('Bournemouth', 'AFC Bournemouth')

# %%
coach_pl = coach_team.merge(pl_coach, how='left', left_on='club_name', right_on='Club')
coach_pl
# Out:
#      coach_id                 name  team_id nationality          club_name  \
# 0          34                  NaN      354         NaN     Crystal Palace
# 1          34                  NaN      354         NaN     Crystal Palace
# 2          34                  NaN      354         NaN     Crystal Palace
# 3          34                  NaN      354         NaN     Crystal Palace
# 4          34                  NaN      354         NaN     Crystal Palace
# ..        ...                  ...      ...         ...                ...
# 265        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 266        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 267        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 268        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
# 269        33  Nuno Espirito Santo      351    Portugal  Nottingham Forest
#
#      league_id                 Name       Nat.               Club  \
# 0            1        Steve Coppell    England     Crystal Palace
# 1            1           Alan Smith    England     Crystal Palace
# 2            1        Steve Coppell    England     Crystal Palace
# 3            1    Attilio Lombardo‡      Italy     Crystal Palace
# 4            1        Tomas Brolin‡     Sweden     Crystal Palace
# ..         ...                  ...        ...                ...
# 265          1         Ron Atkinson    England  Nottingham Forest
# 266          1         Steve Cooper      Wales  Nottingham Forest
# 267          1  Nuno Espírito Santo   Portugal  Nottingham Forest
# 268          1     Ange Postecoglou  Australia  Nottingham Forest
# 269          1          Sean Dyche†    England  Nottingham Forest
#
#                   From  ... Duration(days) Years inLeague        Ref.  \
# 0          3 June 1984  ...           3270      1992–1993        [67]
# 1          3 June 1993  ...            711      1994–1995        [67]
# 2     27 February 1997  ...            379      1997–1998        [67]
# 3        13 March 1998  ...             47           1998        [67]
# 4        13 March 1998  ...             47           1998        [67]
# ..                 ...  ...            ...            ...         ...
# 265    11 January 1999  ...            125           1999  [112][113]
# 266  21 September 2021  ...            819      2022–2023
# 267   20 December 2023  ...            629      2023–2025
# 268   9 September 2025  ...             39           2025
# 269    21 October 2025  ...             66          2025–
#
#     is_incumbent  is_caretaker  is_non_pl_incumbent  from_check until_check  \
# 0              0             0                    0  1984-06-03  1993-05-17
# 1              0             0                    0  1993-06-03  1995-05-15
# 2              0             0                    0  1997-02-27  1998-03-13
# 3              0             1                    0  1998-03-13  1998-04-29
# 4              0             1                    0  1998-03-13  1998-04-29
# ..           ...           ...                  ...         ...         ...
# 265            0             0                    0  1999-01-11  1999-05-16
# 266            0             0                    0  2021-09-21  2023-12-19
# 267            0             0                    0  2023-12-20  2025-09-09
# 268            0             0                    0  2025-09-09  2025-10-18
# 269            1             0                    0  2025-10-21  2025-12-28
#
#       until_at    from_at
# 0   1993-05-17 1984-06-03
# 1   1995-05-15 1993-06-03
# 2   1998-03-13 1997-02-27
# 3   1998-04-29 1998-03-13
# 4   1998-04-29 1998-03-13
# ..         ...        ...
# 265 1999-05-16 1999-01-11
# 266 2023-12-19 2021-09-21
# 267 2025-09-09 2023-12-20
# 268 2025-10-18 2025-09-09
# 269 2025-12-28 2025-10-21
#
# [270 rows x 21 columns]

# %%
coach_pl.isnull().any()
# Out:
# coach_id               False
# name                    True
# team_id                False
# nationality             True
# club_name              False
# league_id              False
# Name                   False
# Nat.                   False
# Club                   False
# From                   False
# Until                  False
# Duration(days)         False
# Years inLeague         False
# Ref.                   False
# is_incumbent           False
# is_caretaker           False
# is_non_pl_incumbent    False
# from_check             False
# until_check            False
# until_at               False
# from_at                False
# dtype: bool

# %%
coach_pl[coach_pl['name'].isnull()].head(5)
# Out:
#    coach_id name  team_id nationality       club_name  league_id  \
# 0        34  NaN      354         NaN  Crystal Palace          1
# 1        34  NaN      354         NaN  Crystal Palace          1
# 2        34  NaN      354         NaN  Crystal Palace          1
# 3        34  NaN      354         NaN  Crystal Palace          1
# 4        34  NaN      354         NaN  Crystal Palace          1
#
#                 Name     Nat.            Club              From  ...  \
# 0      Steve Coppell  England  Crystal Palace       3 June 1984  ...
# 1         Alan Smith  England  Crystal Palace       3 June 1993  ...
# 2      Steve Coppell  England  Crystal Palace  27 February 1997  ...
# 3  Attilio Lombardo‡    Italy  Crystal Palace     13 March 1998  ...
# 4      Tomas Brolin‡   Sweden  Crystal Palace     13 March 1998  ...
#
#   Duration(days) Years inLeague  Ref. is_incumbent  is_caretaker  \
# 0           3270      1992–1993  [67]            0             0
# 1            711      1994–1995  [67]            0             0
# 2            379      1997–1998  [67]            0             0
# 3             47           1998  [67]            0             1
# 4             47           1998  [67]            0             1
#
#    is_non_pl_incumbent  from_check until_check   until_at    from_at
# 0                    0  1984-06-03  1993-05-17 1993-05-17 1984-06-03
# 1                    0  1993-06-03  1995-05-15 1995-05-15 1993-06-03
# 2                    0  1997-02-27  1998-03-13 1998-03-13 1997-02-27
# 3                    0  1998-03-13  1998-04-29 1998-04-29 1998-03-13
# 4                    0  1998-03-13  1998-04-29 1998-04-29 1998-03-13
#
# [5 rows x 21 columns]

# %%
coach_pl.columns
# Out:
# Index(['coach_id', 'name', 'team_id', 'nationality', 'club_name', 'league_id',
#        'Name', 'Nat.', 'Club', 'From', 'Until', 'Duration(days)',
#        'Years inLeague', 'Ref.', 'is_incumbent', 'is_caretaker',
#        'is_non_pl_incumbent', 'from_check', 'until_check', 'until_at',
#        'from_at'],
#       dtype='object')

# %%
coach_pl_scd = coach_pl[['coach_id', 'team_id', 'club_name', 'league_id','Name', 'Nat.','is_incumbent', 'is_caretaker', 'is_non_pl_incumbent','from_at','until_at']]
coach_pl_scd
# Out:
#      coach_id  team_id          club_name  league_id                 Name  \
# 0          34      354     Crystal Palace          1        Steve Coppell
# 1          34      354     Crystal Palace          1           Alan Smith
# 2          34      354     Crystal Palace          1        Steve Coppell
# 3          34      354     Crystal Palace          1    Attilio Lombardo‡
# 4          34      354     Crystal Palace          1        Tomas Brolin‡
# ..        ...      ...                ...        ...                  ...
# 265        33      351  Nottingham Forest          1         Ron Atkinson
# 266        33      351  Nottingham Forest          1         Steve Cooper
# 267        33      351  Nottingham Forest          1  Nuno Espírito Santo
# 268        33      351  Nottingham Forest          1     Ange Postecoglou
# 269        33      351  Nottingham Forest          1          Sean Dyche†
#
#           Nat.  is_incumbent  is_caretaker  is_non_pl_incumbent    from_at  \
# 0      England             0             0                    0 1984-06-03
# 1      England             0             0                    0 1993-06-03
# 2      England             0             0                    0 1997-02-27
# 3        Italy             0             1                    0 1998-03-13
# 4       Sweden             0             1                    0 1998-03-13
# ..         ...           ...           ...                  ...        ...
# 265    England             0             0                    0 1999-01-11
# 266      Wales             0             0                    0 2021-09-21
# 267   Portugal             0             0                    0 2023-12-20
# 268  Australia             0             0                    0 2025-09-09
# 269    England             1             0                    0 2025-10-21
#
#       until_at
# 0   1993-05-17
# 1   1995-05-15
# 2   1998-03-13
# 3   1998-04-29
# 4   1998-04-29
# ..         ...
# 265 1999-05-16
# 266 2023-12-19
# 267 2025-09-09
# 268 2025-10-18
# 269 2025-12-28
#
# [270 rows x 11 columns]

# %%
coach_pl_scd = coach_pl_scd.rename({
    'Name':'coach_name',
    'Nat.':'nationality',
    'club_name': 'team_name',
    'from_at': 'valid_from',
    'until_at': 'valid_to'
}, axis=1)

coach_pl_scd
# Out:
#      coach_id  team_id          team_name  league_id           coach_name  \
# 0          34      354     Crystal Palace          1        Steve Coppell
# 1          34      354     Crystal Palace          1           Alan Smith
# 2          34      354     Crystal Palace          1        Steve Coppell
# 3          34      354     Crystal Palace          1    Attilio Lombardo‡
# 4          34      354     Crystal Palace          1        Tomas Brolin‡
# ..        ...      ...                ...        ...                  ...
# 265        33      351  Nottingham Forest          1         Ron Atkinson
# 266        33      351  Nottingham Forest          1         Steve Cooper
# 267        33      351  Nottingham Forest          1  Nuno Espírito Santo
# 268        33      351  Nottingham Forest          1     Ange Postecoglou
# 269        33      351  Nottingham Forest          1          Sean Dyche†
#
#     nationality  is_incumbent  is_caretaker  is_non_pl_incumbent valid_from  \
# 0       England             0             0                    0 1984-06-03
# 1       England             0             0                    0 1993-06-03
# 2       England             0             0                    0 1997-02-27
# 3         Italy             0             1                    0 1998-03-13
# 4        Sweden             0             1                    0 1998-03-13
# ..          ...           ...           ...                  ...        ...
# 265     England             0             0                    0 1999-01-11
# 266       Wales             0             0                    0 2021-09-21
# 267    Portugal             0             0                    0 2023-12-20
# 268   Australia             0             0                    0 2025-09-09
# 269     England             1             0                    0 2025-10-21
#
#       valid_to
# 0   1993-05-17
# 1   1995-05-15
# 2   1998-03-13
# 3   1998-04-29
# 4   1998-04-29
# ..         ...
# 265 1999-05-16
# 266 2023-12-19
# 267 2025-09-09
# 268 2025-10-18
# 269 2025-12-28
#
# [270 rows x 11 columns]

# %%
coach_pl_scd['coach_name'] = coach_pl_scd['coach_name'].str.replace('†|‡|§', '', regex=True)
coach_pl_scd
# Out:
#      coach_id  team_id          team_name  league_id           coach_name  \
# 0          34      354     Crystal Palace          1        Steve Coppell
# 1          34      354     Crystal Palace          1           Alan Smith
# 2          34      354     Crystal Palace          1        Steve Coppell
# 3          34      354     Crystal Palace          1     Attilio Lombardo
# 4          34      354     Crystal Palace          1         Tomas Brolin
# ..        ...      ...                ...        ...                  ...
# 265        33      351  Nottingham Forest          1         Ron Atkinson
# 266        33      351  Nottingham Forest          1         Steve Cooper
# 267        33      351  Nottingham Forest          1  Nuno Espírito Santo
# 268        33      351  Nottingham Forest          1     Ange Postecoglou
# 269        33      351  Nottingham Forest          1           Sean Dyche
#
#     nationality  is_incumbent  is_caretaker  is_non_pl_incumbent valid_from  \
# 0       England             0             0                    0 1984-06-03
# 1       England             0             0                    0 1993-06-03
# 2       England             0             0                    0 1997-02-27
# 3         Italy             0             1                    0 1998-03-13
# 4        Sweden             0             1                    0 1998-03-13
# ..          ...           ...           ...                  ...        ...
# 265     England             0             0                    0 1999-01-11
# 266       Wales             0             0                    0 2021-09-21
# 267    Portugal             0             0                    0 2023-12-20
# 268   Australia             0             0                    0 2025-09-09
# 269     England             1             0                    0 2025-10-21
#
#       valid_to
# 0   1993-05-17
# 1   1995-05-15
# 2   1998-03-13
# 3   1998-04-29
# 4   1998-04-29
# ..         ...
# 265 1999-05-16
# 266 2023-12-19
# 267 2025-09-09
# 268 2025-10-18
# 269 2025-12-28
#
# [270 rows x 11 columns]

# %%
coach_pl_scd.isnull().any()
# Out:
# coach_id               False
# team_id                False
# team_name              False
# league_id              False
# coach_name             False
# nationality            False
# is_incumbent           False
# is_caretaker           False
# is_non_pl_incumbent    False
# valid_from             False
# valid_to               False
# dtype: bool

# %%
coach_pl_scd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   coach_id             270 non-null    int64
#  1   team_id              270 non-null    int64
#  2   team_name            270 non-null    object
#  3   league_id            270 non-null    int64
#  4   coach_name           270 non-null    object
#  5   nationality          270 non-null    object
#  6   is_incumbent         270 non-null    int64
#  7   is_caretaker         270 non-null    int64
#  8   is_non_pl_incumbent  270 non-null    int64
#  9   valid_from           270 non-null    datetime64[ns]
#  10  valid_to             270 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(6), object(3)
# memory usage: 23.3+ KB

# %%
# Load the csv file to database

pipe.export_df_to_sql(coach_pl_scd, "coaches_scd_test")
# Out:
# --- Checking/Creating Database: 'football' ---
# Database 'football' is ready.
# --- Exporting DataFrame to table 'coaches_scd_test' ---
# Successfully exported 270 rows to 'coaches_scd_test'.
